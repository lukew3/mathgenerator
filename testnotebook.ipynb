# %%
import mathgenerator as mg 
import random
random.seed(123)

# %%
mg.generate_context()
# Out:
# {'problem': '$34\\div12=$',
#  'solution': '2.83',
#  'reward_type': 'float',
#  'topic': 'basic_math',
#  'subtopic': 'fraction_to_decimal'}

# %%
choice = random.choice(mg.FLOAT_GENERATORS)()

# %%
choice
# Out:
# ('Simplify $27^{5^{2}}$', '205891132094649')

# %%
# basic_algebra, combine_like_terms, compound_interest, distance_two_points, int_matrix_22_determinant, linear_equations, log, simple_interest, system_of_equations, vector_dot
# absolute_difference, addition, cube_root, divide_fractions, division, exponentiation, factorial, fraction_multiplication, fraction_to_decimal, greatest_common_divisor, multiplication, percentage, percentage_difference, percentage_error, power_of_powers, square, square_root, subtraction
# definite_integral, power_rule_differentiation,
# binary_to_decimal

# %%
for i in range(1000):
    print(mg.generate_float())
# Out:
# ('$\\sqrt{1}=$', '1')
# ('What is the cube root of: $\\sqrt[3]{550}=$ to 2 decimal places?', '8.19')
# ('$\\frac{6}{3}\\cdot\\frac{1}{3}=$', 0.6666666666666666)
# ('$|43--15|=$', '58')
# ('What is the percentage difference between $62$ and $41$?', '40.78')
# ('$7x + 2 = 8$', 'x')
# ('Compound interest for a principle amount of $1108$ dollars, $6$% rate of interest and for a time period of $8$ years is $=$', '1765.98')
# ('Find the distance between $(-18, -15)$ and $(-11, -12)$', '7.62')
# ('$1^2=$', '1')
# ('$[7, 16, 10]\\cdot[-4, 10, -18]=$', '-48')
# ('Simplify $20^{6^{9}}$', '18014398509481984000000000000000000000000000000000000000000000000000000')
# ('$16^2=$', '256')
# ('$log_{2}(64)=$', '6')
# ('What is the cube root of: $\\sqrt[3]{915}=$ to 2 decimal places?', '9.71')
# ('Simplify $42^{9^{7}}$', '1839523308262426323813912864704838046368599461659868111385875521432742771488335109880777593478591807488')
# ('What is $69$% of $82$?', '56.58')
# ('$20^2=$', '400')
# ...

# %%
"fart".strip('$')
# Out:
# 'fart'
